# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\Bala murukan\Desktop\CSE\Dataset\Lung-Cancer-Prediction-Analysis\lung_cancer\lung_cancer_Dataset.csv')

# %%
df.shape
# Out:
# (220632, 24)

# %%
df.head()
# Out:
#    ID       Country  Population_Size  Age  Gender Smoker  Years_of_Smoking  \
# 0   1         China             1400   80    Male    Yes                30
# 1   2          Iran               84   53    Male     No                 0
# 2   3        Mexico              128   47    Male    Yes                12
# 3   4     Indonesia              273   39  Female     No                 0
# 4   5  South Africa               59   44  Female     No                 0
#
#    Cigarettes_per_Day Passive_Smoker Family_History  ...  \
# 0                  29             No             No  ...
# 1                   0            Yes             No  ...
# 2                   6            Yes             No  ...
# 3                   0             No            Yes  ...
# 4                   0            Yes             No  ...
#
#   Air_Pollution_Exposure Occupational_Exposure  Indoor_Pollution  \
# 0                    Low                   Yes                No
# ...

# %%
df.tail()
# Out:
#             ID       Country  Population_Size  Age  Gender Smoker  \
# 220627  220628      Thailand               70   55    Male    Yes
# 220628  220629  South Africa               59   66    Male     No
# 220629  220630       Vietnam               97   46    Male     No
# 220630  220631      Ethiopia              120   36    Male     No
# 220631  220632       Germany               83   60  Female     No
#
#         Years_of_Smoking  Cigarettes_per_Day Passive_Smoker Family_History  \
# 220627                 4                  10             No            Yes
# 220628                 0                   0             No             No
# 220629                 0                   0             No             No
# 220630                 0                   0            Yes            Yes
# 220631                 0                   0             No             No
#
#         ... Air_Pollution_Exposure Occupational_Exposure  Indoor_Pollution  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Country', 'Population_Size', 'Age', 'Gender', 'Smoker',
#        'Years_of_Smoking', 'Cigarettes_per_Day', 'Passive_Smoker',
#        'Family_History', 'Lung_Cancer_Diagnosis', 'Cancer_Stage',
#        'Survival_Years', 'Adenocarcinoma_Type', 'Air_Pollution_Exposure',
#        'Occupational_Exposure', 'Indoor_Pollution', 'Healthcare_Access',
#        'Early_Detection', 'Treatment_Type', 'Developed_or_Developing',
#        'Annual_Lung_Cancer_Deaths', 'Lung_Cancer_Prevalence_Rate',
#        'Mortality_Rate'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# ID                                  0
# Country                             0
# Population_Size                     0
# Age                                 0
# Gender                              0
# Smoker                              0
# Years_of_Smoking                    0
# Cigarettes_per_Day                  0
# Passive_Smoker                      0
# Family_History                      0
# Lung_Cancer_Diagnosis               0
# Cancer_Stage                   211671
# Survival_Years                      0
# Adenocarcinoma_Type                 0
# Air_Pollution_Exposure              0
# Occupational_Exposure               0
# Indoor_Pollution                    0
# Healthcare_Access                   0
# Early_Detection                     0
# Treatment_Type                 213968
# Developed_or_Developing             0
# Annual_Lung_Cancer_Deaths           0
# Lung_Cancer_Prevalence_Rate         0
# Mortality_Rate                      0
# dtype: int64

# %%
df.dtypes
# Out:
# ID                               int64
# Country                         object
# Population_Size                  int64
# Age                              int64
# Gender                          object
# Smoker                          object
# Years_of_Smoking                 int64
# Cigarettes_per_Day               int64
# Passive_Smoker                  object
# Family_History                  object
# Lung_Cancer_Diagnosis           object
# Cancer_Stage                    object
# Survival_Years                   int64
# Adenocarcinoma_Type             object
# Air_Pollution_Exposure          object
# Occupational_Exposure           object
# Indoor_Pollution                object
# Healthcare_Access               object
# Early_Detection                 object
# Treatment_Type                  object
# Developed_or_Developing         object
# Annual_Lung_Cancer_Deaths        int64
# Lung_Cancer_Prevalence_Rate    float64
# Mortality_Rate                 float64
# dtype: object

# %%
df['Country'].unique()
# Out:
# array(['China', 'Iran', 'Mexico', 'Indonesia', 'South Africa', 'India',
#        'Myanmar', 'Ethiopia', 'Nigeria', 'Egypt', 'Italy', 'France',
#        'Germany', 'Brazil', 'Turkey', 'Thailand', 'Japan', 'Pakistan',
#        'Philippines', 'Bangladesh', 'Russia', 'Vietnam', 'USA',
#        'DR Congo', 'UK'], dtype=object)

# %%
df['Country'].value_counts()
# Out:
# Country
# Japan           8989
# Ethiopia        8975
# Turkey          8966
# France          8920
# China           8907
# Philippines     8884
# DR Congo        8861
# South Africa    8854
# Mexico          8837
# Nigeria         8829
# Vietnam         8829
# Egypt           8822
# Bangladesh      8821
# Myanmar         8819
# Russia          8804
# Italy           8802
# Brazil          8800
# Iran            8778
# Indonesia       8771
# USA             8769
# India           8752
# Germany         8727
# Pakistan        8723
# Thailand        8709
# UK              8684
# Name: count, dtype: int64

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    110488
# Male      110144
# Name: count, dtype: int64

# %%
df['Smoker'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Smoker'].value_counts()
# Out:
# Smoker
# No     132291
# Yes     88341
# Name: count, dtype: int64

# %%
df['Passive_Smoker'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Passive_Smoker'].value_counts()
# Out:
# Passive_Smoker
# No     154670
# Yes     65962
# Name: count, dtype: int64

# %%
df['Family_History'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Family_History'].value_counts()
# Out:
# Family_History
# No     187807
# Yes     32825
# Name: count, dtype: int64

# %%
df['Lung_Cancer_Diagnosis'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Lung_Cancer_Diagnosis'].value_counts()
# Out:
# Lung_Cancer_Diagnosis
# No     211671
# Yes      8961
# Name: count, dtype: int64

# %%
df['Cancer_Stage'].unique()
# Out:
# array([nan, 'Stage 1', 'Stage 2', 'Stage 3', 'Stage 4'], dtype=object)

# %%
df['Cancer_Stage'].value_counts()
# Out:
# Cancer_Stage
# Stage 4    2387
# Stage 2    2198
# Stage 1    2191
# Stage 3    2185
# Name: count, dtype: int64

# %%
df['Cancer_Stage'] = df['Cancer_Stage'].map({
    'Stage 1': 1,
    'Stage 2': 2,
    'Stage 3': 3,
    'Stage 4': 4
})

# %%
df['Cancer_Stage'].unique()
# Out:
# array([nan,  1.,  2.,  3.,  4.])

# %%
median=df['Cancer_Stage'].median()
df['Cancer_Stage']=df['Cancer_Stage'].fillna(median)

# %%
df['Cancer_Stage'] = df['Cancer_Stage'].map({
   1: 'Stage 1',
   2: 'Stage 2',
   3: 'Stage 3',
   4: 'Stage 4'})

# %%
df['Cancer_Stage'].unique()
# Out:
# array(['Stage 3', 'Stage 1', 'Stage 2', 'Stage 4'], dtype=object)

# %%
df['Adenocarcinoma_Type'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Adenocarcinoma_Type'].value_counts()
# Out:
# Adenocarcinoma_Type
# No     121139
# Yes     99493
# Name: count, dtype: int64

# %%
df['Air_Pollution_Exposure'].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
df['Air_Pollution_Exposure'].value_counts()
# Out:
# Air_Pollution_Exposure
# Medium    110157
# Low        55367
# High       55108
# Name: count, dtype: int64

# %%
df['Occupational_Exposure'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Occupational_Exposure'].value_counts()
# Out:
# Occupational_Exposure
# No     154115
# Yes     66517
# Name: count, dtype: int64

# %%
df['Indoor_Pollution'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Indoor_Pollution'].value_counts()
# Out:
# Indoor_Pollution
# No     169619
# Yes     51013
# Name: count, dtype: int64

# %%
df['Healthcare_Access'].unique()
# Out:
# array(['Poor', 'Good'], dtype=object)

# %%
df['Healthcare_Access'].value_counts()
# Out:
# Healthcare_Access
# Poor    176543
# Good     44089
# Name: count, dtype: int64

# %%
df['Early_Detection'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Early_Detection'].value_counts()
# Out:
# Early_Detection
# No     158913
# Yes     61719
# Name: count, dtype: int64

# %%
df['Treatment_Type'].unique()
# Out:
# array([nan, 'Chemotherapy', 'Radiotherapy', 'Surgery'], dtype=object)

# %%
df['Treatment_Type'].value_counts()
# Out:
# Treatment_Type
# Surgery         2272
# Radiotherapy    2250
# Chemotherapy    2142
# Name: count, dtype: int64

# %%
df['Treatment_Type'] = df['Treatment_Type'].map({
    'Surgery': 1,
    'Chemotherapy': 2,
    'Radiotherapy': 3,
})

# %%
median=df['Treatment_Type'].median()
df['Treatment_Type']=df['Treatment_Type'].fillna(median)

# %%
df['Treatment_Type'].unique()
# Out:
# array([2., 3., 1.])

# %%
df['Treatment_Type'] = df['Treatment_Type'].map({
   1:'Surgery',
    2:'Chemotherapy',
    3:'Radiotherapy'
})

# %%
df['Treatment_Type'].unique()
# Out:
# array(['Chemotherapy', 'Radiotherapy', 'Surgery'], dtype=object)

# %%
df['Developed_or_Developing'].unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %%
df['Developed_or_Developing'].value_counts()
# Out:
# Developed_or_Developing
# Developing    167741
# Developed      52891
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# ID                             0
# Country                        0
# Population_Size                0
# Age                            0
# Gender                         0
# Smoker                         0
# Years_of_Smoking               0
# Cigarettes_per_Day             0
# Passive_Smoker                 0
# Family_History                 0
# Lung_Cancer_Diagnosis          0
# Cancer_Stage                   0
# Survival_Years                 0
# Adenocarcinoma_Type            0
# Air_Pollution_Exposure         0
# Occupational_Exposure          0
# Indoor_Pollution               0
# Healthcare_Access              0
# Early_Detection                0
# Treatment_Type                 0
# Developed_or_Developing        0
# Annual_Lung_Cancer_Deaths      0
# Lung_Cancer_Prevalence_Rate    0
# Mortality_Rate                 0
# dtype: int64

# %%
df.dtypes
# Out:
# ID                               int64
# Country                         object
# Population_Size                  int64
# Age                              int64
# Gender                          object
# Smoker                          object
# Years_of_Smoking                 int64
# Cigarettes_per_Day               int64
# Passive_Smoker                  object
# Family_History                  object
# Lung_Cancer_Diagnosis           object
# Cancer_Stage                    object
# Survival_Years                   int64
# Adenocarcinoma_Type             object
# Air_Pollution_Exposure          object
# Occupational_Exposure           object
# Indoor_Pollution                object
# Healthcare_Access               object
# Early_Detection                 object
# Treatment_Type                  object
# Developed_or_Developing         object
# Annual_Lung_Cancer_Deaths        int64
# Lung_Cancer_Prevalence_Rate    float64
# Mortality_Rate                 float64
# dtype: object

# %%
df.to_csv("cleaned_data.csv", index=False)
